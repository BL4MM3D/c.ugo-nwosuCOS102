# %%
#Adekunle gold delivery shit

import tkinter as tk
from tkinter import messagebox

def welcomeMessage(message):
    # Create a new window for the welcome message
    window = tk.Toplevel(root)
    window.title("Order Complete")
    window.geometry("500x200")
    window.configure(bg="lightblue")

    label_1 = tk.Label(window, text=f"Thank you for your purchase dear customer\n")  # Fixed case
    label_1.pack()
    label_2 = tk.Label(window, text="Your delivery will arrive in 5-6 business days\n")  # Fixed case
    label_2.pack()
    label_3 = tk.Label(window, text="For more information please contact our services.\n")  # Fixed case
    label_3.pack()

def submit():
        # Retrieve input values
    Location = location_entry.get()
    weight = weight_entry.get()

    # Validate username and password
    if location == "Ibeju-Lekki" or "Ibeju Lekki" or "ibeju lekki" or "ibeju-lekki" and weight >= 10:
        welcomeMessage("Your Total elivery fee comes down to 5000 naira")
    elif weight < 10:
        welcomeMessage("Your Total delivery fee comes down to 3500 naira")

    elif location == "Epe" or "epe" and weight >= 10:
        welcomeMessage("Your Total delivery fee comes down to 10,000 naira")
    elif weight < 10:
        welcomeMessage("Your Total delivery fee comes down to 5,000 naira")
    else:
        messagebox.showerror("Login", "Please enter required parameters")

# Create Main window
root = tk.Tk()
root.title("Welcome to Simi services")
root.geometry("500x200")

# Create Weight label and entry
location_label = tk.Label(root, text="Location (Ibeju-Lekki or Epe):")  # Fixed case
location_label.pack()
location_entry = tk.Entry(root)
location_entry.pack()

# Create Weight label and entry
weight_label = tk.Label(root, text="Weight:")  # Fixed case
weight_label.pack()
weight_entry = tk.Entry(root)
weight_entry.pack()

# Create Purchase Button
Purchase_button = tk.Button(root, text="Purchase", command=submit)
Purchase_button.pack()

# Run the main event loop
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\Users\hp\AppData\Local\Programs\Python\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_4476\3763863579.py", line 25, in submit
#     if location == "Ibeju-Lekki" or "Ibeju Lekki" or "ibeju lekki" or "ibeju-lekki" and weight >= 10:
#        ^^^^^^^^
# NameError: name 'location' is not defined. Did you mean: 'Location'?
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\Users\hp\AppData\Local\Programs\Python\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_4476\3763863579.py", line 25, in submit
#     if location == "Ibeju-Lekki" or "Ibeju Lekki" or "ibeju lekki" or "ibeju-lekki" and weight >= 10:
#        ^^^^^^^^
# NameError: name 'location' is not defined. Did you mean: 'Location'?
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\Users\hp\AppData\Local\Programs\Python\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_4476\3763863579.py", line 25, in submit
#     if location == "Ibeju-Lekki" or "Ibeju Lekki" or "ibeju lekki" or "ibeju-lekki" and weight >= 10:
#        ^^^^^^^^
# NameError: name 'location' is not defined. Did you mean: 'Location'?
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\Users\hp\AppData\Local\Programs\Python\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_4476\3763863579.py", line 25, in submit
#     if location == "Ibeju-Lekki" or "Ibeju Lekki" or "ibeju lekki" or "ibeju-lekki" and weight >= 10:
#        ^^^^^^^^
# NameError: name 'location' is not defined. Did you mean: 'Location'?
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\Users\hp\AppData\Local\Programs\Python\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_4476\3763863579.py", line 25, in submit
#     if location == "Ibeju-Lekki" or "Ibeju Lekki" or "ibeju lekki" or "ibeju-lekki" and weight >= 10:
#        ^^^^^^^^
# NameError: name 'location' is not defined. Did you mean: 'Location'?
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\Users\hp\AppData\Local\Programs\Python\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_4476\3763863579.py", line 25, in submit
#     if location == "Ibeju-Lekki" or "Ibeju Lekki" or "ibeju lekki" or "ibeju-lekki" and weight >= 10:
#        ^^^^^^^^
# NameError: name 'location' is not defined. Did you mean: 'Location'?
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\Users\hp\AppData\Local\Programs\Python\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_4476\3763863579.py", line 25, in submit
#     if location == "Ibeju-Lekki" or "Ibeju Lekki" or "ibeju lekki" or "ibeju-lekki" and weight >= 10:
#        ^^^^^^^^
# NameError: name 'location' is not defined. Did you mean: 'Location'?
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\Users\hp\AppData\Local\Programs\Python\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_4476\3763863579.py", line 25, in submit
#     if location == "Ibeju-Lekki" or "Ibeju Lekki" or "ibeju lekki" or "ibeju-lekki" and weight >= 10:
#        ^^^^^^^^
# NameError: name 'location' is not defined. Did you mean: 'Location'?
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\Users\hp\AppData\Local\Programs\Python\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_4476\3763863579.py", line 25, in submit
#     if location == "Ibeju-Lekki" or "Ibeju Lekki" or "ibeju lekki" or "ibeju-lekki" and weight >= 10:
#        ^^^^^^^^
# NameError: name 'location' is not defined. Did you mean: 'Location'?
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\Users\hp\AppData\Local\Programs\Python\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_4476\3763863579.py", line 25, in submit
#     if location == "Ibeju-Lekki" or "Ibeju Lekki" or "ibeju lekki" or "ibeju-lekki" and weight >= 10:
#        ^^^^^^^^
# NameError: name 'location' is not defined. Did you mean: 'Location'?
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\Users\hp\AppData\Local\Programs\Python\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_4476\3763863579.py", line 25, in submit
#     if location == "Ibeju-Lekki" or "Ibeju Lekki" or "ibeju lekki" or "ibeju-lekki" and weight >= 10:
#        ^^^^^^^^
# NameError: name 'location' is not defined. Did you mean: 'Location'?
